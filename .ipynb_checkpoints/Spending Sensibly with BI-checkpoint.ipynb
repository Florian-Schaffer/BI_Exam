# %% [markdown]
# Spending Sensibly with BI
#
# Statistical analysis of customer spending habits

# %%
## Import of needed libraries/functionalities

#import of pandas and basic math-operation libraries
import pandas as pd
import numpy as np

from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#sklearn allows for us to utilize machine learning
from sklearn import datasets, preprocessing, metrics
import sklearn.metrics as sm
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
## Loading of data into dataset and initial observations

dfInit = pd.read_csv('purchasing-behavior.csv',',')

# datatypes contained in file, can give insight in which functions/methods need to be used going forward
# can also give insights into qualitative vs quantitative data values
dfInit.dtypes

# allows a quick look at the size of the dataset
dfInit.shape

# looking at the first five and last five entries of the dataset can reveal an approximate range of values
dfInit.head
# Out:
# C:\Users\Flobobo\AppData\Local\Temp\ipykernel_17588\3678156869.py:3: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   dfInit = pd.read_csv('purchasing-behavior.csv',',')
# <bound method NDFrame.head of      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# ..       ...  ...            ...              ...            ...    ...
# 233      234   40          60000              450            7.2   West
# 234      235   38          59000              430            6.9  North
# ...

# %%
# checking to see if there are empty data entries in the dataset. This will determine how much cleaning of the data is needed. 

dfInit.isna().sum()
# Out:
# user_id               0
# age                   0
# annual_income         0
# purchase_amount       0
# loyalty_score         0
# region                0
# purchase_frequency    0
# dtype: int64

# %%
# this function again will give us an insight into empty values across all of the data, and also shows the extent of sanitization required.
dfInit.isnull().sum()
# Out:
# user_id               0
# age                   0
# annual_income         0
# purchase_amount       0
# loyalty_score         0
# region                0
# purchase_frequency    0
# dtype: int64

# %%
# a concise grid with various statistical descriptors for the data. Especially important are standard deviation and median values. 
dfInit.describe()
# Out:
#           user_id         age  annual_income  purchase_amount  loyalty_score  \
# count  238.000000  238.000000     238.000000       238.000000     238.000000
# mean   119.500000   38.676471   57407.563025       425.630252       6.794118
# std     68.848868    9.351118   11403.875717       140.052062       1.899047
# min      1.000000   22.000000   30000.000000       150.000000       3.000000
# 25%     60.250000   31.000000   50000.000000       320.000000       5.500000
# 50%    119.500000   39.000000   59000.000000       440.000000       7.000000
# 75%    178.750000   46.750000   66750.000000       527.500000       8.275000
# max    238.000000   55.000000   75000.000000       640.000000       9.500000
#
#        purchase_frequency
# count          238.000000
# mean            19.798319
# std              4.562884
# min             10.000000
# 25%             17.000000
# 50%             20.000000
# 75%             23.000000
# max             28.000000

# %%
# Using scatterplots to simply visualize a correlation between annual income as well as loyalty in relation to spending habits. 
# Also shows a regression line to show how close datapoints are to a coherent function

sns.pairplot(dfInit, x_vars=['annual_income','loyalty_score'], y_vars='purchase_frequency', height=5, aspect=0.8, kind='reg')

# %%
#dfDropped = dfInit.drop('user_id')
corr = dfInit.corr()
sns.heatmap(corr, annot=True)
# Out:
# C:\Users\Flobobo\AppData\Local\Temp\ipykernel_17588\3549194211.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = dfInit.corr()
# <Axes: >

# %%
# a deeper investigation of the grid shown above dividing the dataset into bins according to agebrackets

bins = [0,10,20,30,40,50]

dfBinned=
